# %%
import pandas as pd
import numpy as np
import re

# %%
films = pd.read_csv('rotten_tomatoes_movies.csv')

# %%
films.head(40)
# Out:
#                                                    id  \
# 0                                  space-zombie-bingo
# 1                                     the_green_grass
# 2                                           love_lies
# 3                                the_sore_losers_1997
# 4                                dinosaur_island_2002
# 5                                         adrift_2018
# 6                      malta-con-huevo-scrambled-beer
# 7                                    kakabakaba-ka-ba
# 8                                          sundowning
# 9                                1035316-born_to_kill
# 10                   1015331-number_one_with_a_bullet
# 11                                 garden_murder_case
# 12                               margarita_happy_hour
# 13                                 leap_of_faith_2019
# 14                                shake-rattle-roll-3
# 15                                          daag_1973
# 16                              crown_vs_stevens_1936
# 17                                        1221483-paa
# 18               f9ab9165-598c-3ac9-bc3e-a5fb2ac517e5
# 19                                 the_last_gentleman
# 20                             sarah_palin_you_betcha
# 21                        1005521-death_of_a_salesman
# 22                               escape_from_alcatraz
# 23                                            sheffey
# 24                                          wrong_guy
# 25                                          cold_room
# 26                                            s_diary
# 27                                deck_the_halls_2011
# 28                                            alraune
# 29                                    danger_tomorrow
# 30                                   angry_rice_wives
# 31                               a_state_of_mind_2005
# 32                                          mugavaree
# 33                                           the_moth
# 34  standardized_lies_money_and_civil_rights_how_t...
# 35                                         outpatient
# 36                                              cupid
# 37                                   the_in_laws_1979
# 38                                             isteve
# 39                                 campfire_christmas
#
#                                                 title  audienceScore  \
# 0                                 Space Zombie Bingo!           50.0
# 1                                     The Green Grass            NaN
# 2                                          Love, Lies           43.0
# 3                                         Sore Losers           60.0
# 4                                     Dinosaur Island           70.0
# 5                                              Adrift           65.0
# 6                                      Scrambled Beer           55.0
# 7    Kakabakaba ka ba? (Will Your Heart Beat Faster?)           88.0
# 8                                          Sundowning            NaN
# 9                                        Born to Kill           74.0
# 10                           Number One With a Bullet           19.0
# 11                             The Garden Murder Case            NaN
# 12                               Margarita Happy Hour            NaN
# 13    Leap of Faith: William Friedkin on The Exorcist           86.0
# 14                              Shake Rattle & Roll 3           89.0
# 15                                          The Stain           82.0
# 16                                  Crown vs. Stevens           60.0
# 17                                                Paa           67.0
# 18                          A Tale of Love and Desire            NaN
# 19                                 The Last Gentleman            NaN
# 20                           Sarah Palin: You Betcha!           61.0
# 21                                Death of a Salesman           75.0
# 22                               Escape From Alcatraz           85.0
# 23                                            Sheffey           73.0
# 24                                      The Wrong Guy           85.0
# 25                                      The Cold Room           22.0
# 26                                            S Diary           63.0
# 27                                     Deck the Halls            NaN
# 28  Alraune (A Daughter of Destiny) (Mandrake) (Un...           57.0
# 29                                    Danger Tomorrow            NaN
# 30                                   Angry Rice Wives            NaN
# 31                                    A State of Mind           92.0
# 32                                          Mugavaree            NaN
# 33                                           The Moth            NaN
# 34  Standardized Lies, Money & Civil Rights: How T...            NaN
# 35                                         Outpatient            NaN
# 36                                              Cupid           20.0
# 37                                        The In-Laws           83.0
# 38                                             iSteve           39.0
# 39                                 Campfire Christmas           14.0
#
#     tomatoMeter rating                                     ratingContents  \
# 0           NaN    NaN                                                NaN
# 1           NaN    NaN                                                NaN
# 2           NaN    NaN                                                NaN
# 3           NaN    NaN                                                NaN
# 4           NaN    NaN                                                NaN
# 5          69.0  PG-13  ['Injury Images', 'Brief Drug Use', 'Thematic ...
# 6           NaN    NaN                                                NaN
# 7           NaN    NaN                                                NaN
# 8           NaN    NaN                                                NaN
# 9          83.0    NaN                                                NaN
# 10          NaN    NaN                                                NaN
# 11          NaN    NaN                                                NaN
# 12         76.0    NaN                                                NaN
# 13         93.0    NaN                                                NaN
# 14          NaN    NaN                                                NaN
# 15          NaN    NaN                                                NaN
# 16          NaN    NaN                                                NaN
# 17         50.0    NaN                                                NaN
# 18          NaN    NaN                                                NaN
# 19          NaN    NaN                                                NaN
# 20         32.0    NaN                                                NaN
# 21        100.0    NaN                                                NaN
# 22         97.0    NaN                                                NaN
# 23          NaN    NaN                                                NaN
# 24          NaN    NaN                                                NaN
# 25          NaN    NaN                                                NaN
# 26          NaN    NaN                                                NaN
# 27          NaN   TVPG                                         ['V', 'L']
# 28          NaN    NaN                                                NaN
# 29          NaN    NaN                                                NaN
# 30          NaN    NaN                                                NaN
# 31         89.0    NaN                                                NaN
# 32          NaN    NaN                                                NaN
# 33          NaN    NaN                                                NaN
# 34          NaN    NaN                                                NaN
# 35          NaN    NaN                                                NaN
# 36          NaN    NaN                                                NaN
# 37         88.0    NaN                                                NaN
# 38          NaN    NaN                                                NaN
# 39          NaN    NaN                                                NaN
#
#    releaseDateTheaters releaseDateStreaming  runtimeMinutes  \
# 0                  NaN           2018-08-25            75.0
# 1                  NaN           2020-02-11           114.0
# 2                  NaN                  NaN           120.0
# 3                  NaN           2020-10-23            90.0
# 4                  NaN           2017-03-27            80.0
# 5           2018-06-01           2018-08-21           120.0
# 6                  NaN           2015-10-05            88.0
# 7                  NaN                  NaN             NaN
# 8                  NaN                  NaN           123.0
# 9           1947-04-30           2016-05-23            92.0
# 10                 NaN           2012-03-13           103.0
# 11                 NaN           2016-10-20            61.0
# 12          2002-03-22                  NaN            98.0
# 13                 NaN           2020-11-19           104.0
# 14                 NaN           2019-01-04           120.0
# 15                 NaN           2003-11-25           146.0
# 16                 NaN                  NaN            66.0
# 17          2009-12-04                  NaN           133.0
# 18                 NaN                  NaN           103.0
# 19                 NaN                  NaN            80.0
# 20          2011-09-30           2017-03-08            90.0
# 21                 NaN           2016-01-11           135.0
# 22                 NaN           1999-03-09           107.0
# 23                 NaN           2017-10-07           137.0
# 24                 NaN           2013-03-19            87.0
# 25                 NaN                  NaN           105.0
# 26                 NaN                  NaN           107.0
# 27                 NaN           2017-03-10            90.0
# 28                 NaN                  NaN             NaN
# 29                 NaN                  NaN            61.0
# 30                 NaN                  NaN           106.0
# 31          2005-08-10           2007-06-11            93.0
# 32                 NaN           2018-10-27           156.0
# 33                 NaN           2009-07-28            64.0
# 34                 NaN                  NaN            74.0
# 35                 NaN                  NaN           105.0
# 36                 NaN           2016-03-11            94.0
# 37                 NaN           2013-07-02           103.0
# 38                 NaN           2016-09-06            79.0
# 39                 NaN                  NaN            84.0
#
#                                         genre originalLanguage  \
# 0                      Comedy, Horror, Sci-fi          English
# 1                                       Drama          English
# 2                                       Drama           Korean
# 3                  Action, Mystery & thriller          English
# 4               Fantasy, Adventure, Animation          English
# 5                   Adventure, Drama, Romance          English
# 6                                      Comedy          Spanish
# 7                                         NaN              NaN
# 8                                       Drama          English
# 9                                Crime, Drama          English
# 10                               Crime, Drama          English
# 11                         Mystery & thriller          English
# 12                                      Drama          English
# 13            Documentary, Mystery & thriller          English
# 14                             Comedy, Horror          Tagalog
# 15                                      Drama            Hindi
# 16           Crime, Drama, Mystery & thriller          English
# 17                                      Drama            Hindi
# 18                                      Drama  French (France)
# 19                                     Comedy          English
# 20                                Documentary          English
# 21                                      Drama          English
# 22          Mystery & thriller, Drama, Action          English
# 23                                  Biography          English
# 24                                     Comedy          English
# 25                         Mystery & thriller          English
# 26                            Romance, Comedy           Korean
# 27  Holiday, Mystery & thriller, Crime, Drama          English
# 28                                        NaN              NaN
# 29                         Mystery & thriller          English
# 30                                      Drama         Japanese
# 31                                Documentary           Korean
# 32                             Drama, Romance            Tamil
# 33                                      Drama          English
# 34                                Documentary          English
# 35                                      Drama          English
# 36                         Mystery & thriller          English
# 37                                     Comedy          English
# 38                          Biography, Comedy          English
# 39                   Holiday, Romance, Comedy          English
#
#                            director  \
# 0                     George Ormrod
# 1                   Tiffany Edwards
# 2     Park Heung-Sik,Heung-Sik Park
# 3             John Michael McCarthy
# 4                     Will Meugniot
# 5                 Baltasar Kormákur
# 6              Cristobal Valderrama
# 7                      Mike de Leon
# 8                    Jim Comas Cole
# 9                       Robert Wise
# 10                      Jack Smight
# 11                   Edwin L. Marin
# 12                     Ilya Chaiken
# 13            Alexandre O. Philippe
# 14         Peque Gallaga,Lore Reyes
# 15                      Yash Chopra
# 16                   Michael Powell
# 17                         R. Balki
# 18                     Leyla Bouzid
# 19                  Sidney Lanfield
# 20   Nick Broomfield,Joan Churchill
# 21               Volker Schlöndorff
# 22                       Don Siegel
# 23               Katherine Stenholm
# 24                  David Steinberg
# 25                    James Dearden
# 26                   Jong-kwan Kwon
# 27                    Ron Underwood
# 28                    Henrik Galeen
# 29                     Terry Bishop
# 30                 Katsuhide Motoki
# 31                    Daniel Gordon
# 32                       V.Z. Durai
# 33                    Fred Newmeyer
# 34  Jim del Conte,Daniel Hornberger
# 35                      Alec Carlen
# 36                    Doug Campbell
# 37                    Arthur Hiller
# 38                       Ryan Perez
# 39                David I. Strasser
#
#                                               writer boxOffice  \
# 0                         George Ormrod,John Sabotta       NaN
# 1                                    Tiffany Edwards       NaN
# 2             Ha Young-Joon,Jeon Yun-su,Song Hye-jin       NaN
# 3                              John Michael McCarthy       NaN
# 4                                           John Loy       NaN
# 5   Aaron Kandell,Jordan Kandell,David Branson Smith    $31.4M
# 6                               Cristobal Valderrama       NaN
# 7                                                NaN       NaN
# 8                                                NaN       NaN
# 9                        Eve Greene,Richard Macaulay       NaN
# 10                                               NaN       NaN
# 11                                               NaN       NaN
# 12                                      Ilya Chaiken    $11.5K
# 13                             Alexandre O. Philippe       NaN
# 14                                               NaN       NaN
# 15                         Yash Chopra,Gulshan Nanda       NaN
# 16                                    Brock Williams       NaN
# 17                                          R. Balki   $199.2K
# 18                                      Leyla Bouzid       NaN
# 19                                               NaN       NaN
# 20                                               NaN    $10.5K
# 21                                               NaN       NaN
# 22                                    Richard Tuggle       NaN
# 23                                        Tim Rogers       NaN
# 24                                               NaN       NaN
# 25                                               NaN       NaN
# 26                    Park Sung-kyung,Jong-kwan Kwon       NaN
# 27                                    Howard Burkons       NaN
# 28                                               NaN       NaN
# 29                           Guy Deghy,Charles Frank       NaN
# 30                                    Kaori Tanimoto       NaN
# 31                                               NaN    $41.5K
# 32                                        V.Z. Durai       NaN
# 33                                               NaN       NaN
# 34                                               NaN       NaN
# 35                                       Alec Carlen       NaN
# 36                                     David Benullo       NaN
# 37                                               NaN       NaN
# 38                                        Ryan Perez       NaN
# 39                                        Anna White       NaN
#
#             distributor  soundMix
# 0                   NaN       NaN
# 1                   NaN       NaN
# 2                   NaN       NaN
# 3                   NaN       NaN
# 4                   NaN       NaN
# 5             STX Films       NaN
# 6                   NaN       NaN
# 7                   NaN       NaN
# 8                   NaN       NaN
# 9                   NaN       NaN
# 10                  NaN       NaN
# 11                  NaN       NaN
# 12    Passport Pictures  Surround
# 13                  NaN       NaN
# 14                  NaN       NaN
# 15                  NaN       NaN
# 16                  NaN       NaN
# 17         Big Pictures       NaN
# 18                  NaN       NaN
# 19                  NaN       NaN
# 20  Freestyle Releasing       NaN
# 21                  NaN    Stereo
# 22                  NaN       NaN
# 23                  NaN       NaN
# 24                  NaN       NaN
# 25                  NaN       NaN
# 26                  NaN       NaN
# 27                  NaN       NaN
# 28                  NaN       NaN
# 29                  NaN       NaN
# 30                  NaN       NaN
# 31        Kino Pictures       NaN
# 32                  NaN       NaN
# 33                  NaN       NaN
# 34                  NaN       NaN
# 35                  NaN       NaN
# 36                  NaN    Stereo
# 37                  NaN       NaN
# 38                  NaN       NaN
# 39                  NaN       NaN

# %%
films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143258 entries, 0 to 143257
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    143258 non-null  object
#  1   title                 142891 non-null  object
#  2   audienceScore         73248 non-null   float64
#  3   tomatoMeter           33877 non-null   float64
#  4   rating                13991 non-null   object
#  5   ratingContents        13991 non-null   object
#  6   releaseDateTheaters   30773 non-null   object
#  7   releaseDateStreaming  79420 non-null   object
#  8   runtimeMinutes        129431 non-null  float64
#  9   genre                 132175 non-null  object
#  10  originalLanguage      129400 non-null  object
#  11  director              139064 non-null  object
#  12  writer                90116 non-null   object
#  13  boxOffice             14743 non-null   object
#  14  distributor           23005 non-null   object
#  15  soundMix              15917 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 17.5+ MB

# %%
films.shape
# Out:
# (143258, 16)

# %%
films.title.isna().sum()
# Out:
# 367

# %% [markdown]
# I will drop rows without titles

# %%
films = films.dropna(subset=['title'])

# %%
films.title.isna().sum()
# Out:
# 0

# %%
films.isna().sum() / len(films) * 100
# Out:
# id                       0.000000
# title                    0.000000
# audienceScore           48.738549
# tomatoMeter             76.291719
# rating                  90.212120
# ratingContents          90.212120
# releaseDateTheaters     78.471702
# releaseDateStreaming    44.447166
# runtimeMinutes           9.463157
# genre                    7.546312
# originalLanguage         9.488351
# director                 2.730053
# writer                  36.963140
# boxOffice               89.683745
# distributor             83.905214
# soundMix                88.863539
# dtype: float64

# %% [markdown]
# I will encode both NaN for audiencaScore and TomatoMeter as 0, so that I can recognize the rows where there is no rating in the future. I will exclude these in the analysis of stats for ratings

# %%
films['audienceScore'].fillna(0, inplace=True)
films['tomatoMeter'].fillna(0, inplace=True)

# %%
films['rating'].value_counts()
# Out:
# R        7733
# PG-13    3445
# PG       1910
# TVPG      424
# TV14      395
# TVMA       57
# NC-17      19
# TVG         1
# TVY7        1
# G           1
# Name: rating, dtype: int64

# %% [markdown]
# I am going to group all less frequent ratings in other and replace the NaNs with the string 'unknown'

# %%
films['rating'].fillna('unknown', inplace=True)

# %%
def filter_ratings(x):
    if x in ['R', 'PG-13', 'PG', 'unknown']:
        return x
    else:
        return 'other'

# %%
films['rating'] = films['rating'].apply(filter_ratings)

# %%
films['rating'].value_counts(dropna=False)
# Out:
# unknown    128905
# R            7733
# PG-13        3445
# PG           1910
# other         898
# Name: rating, dtype: int64

# %%
films['ratingContents'].value_counts()
# Out:
# ['Language']                                                                                   365
# ['V']                                                                                          154
# ['Some Language']                                                                              143
# ['Some Violence']                                                                              126
# ['Violence']                                                                                   105
#                                                                                               ...
# ['Language', 'Drug Material', 'Nudity', 'Sexual Content', 'Strong Violence']                     1
# ['A Disturbing Image', 'Some Thematic Material']                                                 1
# ['Pervasive Sexual Content', 'Aberrant Sexuality', 'Some Drug Material', 'Strong Language']      1
# ['Drinking', 'Crude Humor', 'Language', 'Strong Sexual Content']                                 1
# ['Language', 'Crude and Suggestive Material', 'Partying']                                        1
# Name: ratingContents, Length: 8352, dtype: int64

# %% [markdown]
# Going to replace the NaN in films['ratingContents'] with empty list to maintain the same data type

# %%
films['ratingContents'] = films['ratingContents'].apply(lambda x: [] if pd.isna(x) else x)

# %%
films['releaseDateTheaters'].dtype
# Out:
# dtype('O')

# %%
films['releaseDateTheaters'] = pd.to_datetime(films['releaseDateTheaters'], errors='coerce')

# %%
films['releaseDateTheaters'].dtype
# Out:
# dtype('<M8[ns]')

# %%
films['releaseDateTheaters'].isna().sum()
# Out:
# 112129

# %% [markdown]
# I am going to replace the NaNs with 1800-01-01, so I will able to recognize them in the future

# %%
films['releaseDateTheaters'].fillna(pd.to_datetime('1800-01-01'), inplace=True)

# %% [markdown]
# Same for releaseDateStreaming

# %%
films['releaseDateStreaming'] = pd.to_datetime(films['releaseDateStreaming'], errors='coerce')
films['releaseDateStreaming'].fillna(pd.to_datetime('1800-01-01'), inplace=True)

# %%
films.isna().sum() / len(films) * 100
# Out:
# id                       0.000000
# title                    0.000000
# audienceScore            0.000000
# tomatoMeter              0.000000
# rating                   0.000000
# ratingContents           0.000000
# releaseDateTheaters      0.000000
# releaseDateStreaming     0.000000
# runtimeMinutes           9.463157
# genre                    7.546312
# originalLanguage         9.488351
# director                 2.730053
# writer                  36.963140
# boxOffice               89.683745
# distributor             83.905214
# soundMix                88.863539
# dtype: float64

# %%
films['runtimeMinutes'].describe()
# Out:
# count    129369.000000
# mean         93.708841
# std          28.128291
# min           1.000000
# 25%          84.000000
# 50%          92.000000
# 75%         103.000000
# max        2700.000000
# Name: runtimeMinutes, dtype: float64

# %% [markdown]
# I will replace NaNs with 0, so I can still recognize them

# %%
films['runtimeMinutes'].fillna(0, inplace=True)

# %%
films['genre'].value_counts()
# Out:
# Drama                                          27842
# Documentary                                    15155
# Comedy                                         11509
# Mystery & thriller                              7009
# Comedy, Drama                                   5476
#                                                ...
# Fantasy, Drama, Musical                            1
# Holiday, Drama, Musical                            1
# Drama, War, Adventure, Action                      1
# Action, Adventure, Comedy, Drama, Animation        1
# Western, Comedy, Animation                         1
# Name: genre, Length: 2911, dtype: int64

# %%
films['genre'].fillna('unknown', inplace=True)

# %%
films['originalLanguage'].value_counts()
# Out:
# English            84989
# Spanish             4785
# Japanese            3480
# Hindi               3307
# French (Canada)     3281
#                    ...
# Bhojpuri               1
# Hawaiian               1
# Yoruba                 1
# smi                    1
# Aramaic                1
# Name: originalLanguage, Length: 112, dtype: int64

# %%
films['originalLanguage'].fillna('unknown', inplace=True)

# %%
films['originalLanguage'].value_counts()
# Out:
# English     84989
# unknown     13558
# Spanish      4785
# Japanese     3480
# Hindi        3307
#             ...
# Bhojpuri        1
# Yoruba          1
# Hawaiian        1
# smi             1
# Aramaic         1
# Name: originalLanguage, Length: 113, dtype: int64

# %%
films['director'].value_counts()
# Out:
# Unknown Director                                  3541
# David DeCoteau                                     129
# Sam Newfield                                       123
# Fred Olen Ray                                       93
# Joseph Kane                                         84
#                                                   ...
# Kevin Higgins                                        1
# Laurence Jarvik                                      1
# Anna-Elizabeth Shakespeare,Hillary Shakespeare       1
# Amy French                                           1
# Peter Georgi                                         1
# Name: director, Length: 62187, dtype: int64

# %%
films['director'].fillna('Unknown Director', inplace=True)

# %%
films['writer'].value_counts()
# Out:
# Jing Wong                        48
# Barbara Kymlicka                 46
# Woody Allen                      38
# Kuang Ni                         37
# Christine Conradt                37
#                                  ..
# Kuba Mikurda                      1
# Gail Parent                       1
# Brian Miller                      1
# Jo Enaje                          1
# David J. Francis,Mike Masters     1
# Name: writer, Length: 67249, dtype: int64

# %%
films['writer'].fillna('Unknown Writer', inplace=True)

# %%
films['boxOffice'].value_counts()
# Out:
# $1.1M      118
# $1.2M      100
# $1.0M       97
# $1.3M       97
# $1.6M       70
#           ...
# $228.4M      1
# $86.5K       1
# $160.4K      1
# $129.4K      1
# $218.3K      1
# Name: boxOffice, Length: 4862, dtype: int64

# %% [markdown]
# Going to replace NaNs with 0, so I will remember in the future

# %%
films['boxOffice'].fillna('0', inplace=True)

# %%
def convert_dollars_to_floats(x):
    no_dollar = x.replace('$', '')
    if 'M' in no_dollar:
        float_n = float(no_dollar.replace('M', '')) * 1000000
    elif 'K' in no_dollar:
        float_n = float(no_dollar.replace('K', '')) * 1000
    else:
        float_n = float(no_dollar)   
    int_n = int(float_n)
    return int_n

# %%
convert_dollars_to_floats('$86.5K')
# Out:
# 86500

# %%
films['boxOffice'] = films['boxOffice'].apply(convert_dollars_to_floats)

# %%
films['distributor'].value_counts()
# Out:
# Paramount Pictures                                                                                                           994
# 20th Century Fox                                                                                                             745
# Universal Pictures                                                                                                           737
# Warner Bros. Pictures                                                                                                        668
# Metro-Goldwyn-Mayer                                                                                                          603
#                                                                                                                             ...
# Tartan Films USA, TLA Releasing                                                                                                1
# Cinerama Releasing Corporation [us], Anchor Bay Entertainment                                                                  1
# Image Entertainment Inc., Sinister Cinema, Media Home Entertainment, Metro-Goldwyn-Mayer Distributing Corp., Gorgon Video      1
# Mind Leech Productions                                                                                                         1
# American Cinema                                                                                                                1
# Name: distributor, Length: 3694, dtype: int64

# %%
films['soundMix'].value_counts()
# Out:
# Surround                                                    4074
# Dolby Digital                                               2374
# Stereo                                                      2080
# Mono                                                        1246
# Stereo, Surround                                             473
#                                                             ...
# Dolby, Surround, Dolby A                                       1
# Magnetic Stereo 6 Track, Dolby A, Surround, Dolby Stereo       1
# Dolby Stereo, Dolby SRD, SDDS                                  1
# Vitaphone                                                      1
# Dolby SR, Dolby SRD                                            1
# Name: soundMix, Length: 551, dtype: int64

# %% [markdown]
# I am going to drop both soundMix and distributor because they contain many NaNs and do not provide essential information for this research

# %%
films.drop(['distributor', 'soundMix'], axis=1, inplace=True)

# %%
films.isna().sum() / len(films) * 100
# Out:
# id                      0.0
# title                   0.0
# audienceScore           0.0
# tomatoMeter             0.0
# rating                  0.0
# ratingContents          0.0
# releaseDateTheaters     0.0
# releaseDateStreaming    0.0
# runtimeMinutes          0.0
# genre                   0.0
# originalLanguage        0.0
# director                0.0
# writer                  0.0
# boxOffice               0.0
# dtype: float64

# %%
films.to_csv('films_NaNs_treated.csv', index=False)
